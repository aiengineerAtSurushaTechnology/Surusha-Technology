# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_chem_pro = pd.read_csv(r"D:\projects dataset\PubChem\PubChem_compound_list_woVn-cpQr-yYwifbpaNu9lDW67Y1nfQNjijvQZU5_UCVIME.csv",low_memory=False)
                           
df_chem_pro.head()
# Out:
#    cid                                           cmpdname  \
# 0    2  1-Propanaminium, 2-(acetyloxy)-3-carboxy-N,N,N...
# 1    4                                 1-Aminopropan-2-ol
# 2    6                        1-Chloro-2,4-dinitrobenzene
# 3    7                                     9-Ethyladenine
# 4    9  (2,3,4,5,6-Pentahydroxycyclohexyl) dihydrogen ...
#
#                                          cmpdsynonym      mw          mf  \
# 0  1-Propanaminium, 2-(acetyloxy)-3-carboxy-N,N,N...  204.24   C9H18NO4+
# 1  1-Aminopropan-2-ol|1-AMINO-2-PROPANOL|78-96-6|...   75.11      C3H9NO
# 2  1-chloro-2,4-dinitrobenzene|2,4-Dinitrochlorob...  202.55  C6H3ClN2O4
# 3  9-Ethyladenine|9-ethyl-9h-purin-6-amine|2715-6...  163.18      C7H9N5
# 4  (2,3,4,5,6-pentahydroxycyclohexyl) dihydrogen ...  260.14    C6H13O9P
#
#    polararea  complexity  xlogp  heavycnt  hbonddonor  ...  \
# 0       63.6       219.0   -0.3        14           1  ...
# ...

# %%
df_chem_pro.isnull().sum()
# Out:
# cid                  0
# cmpdname             2
# cmpdsynonym       1853
# mw                   0
# mf                   0
# polararea            0
# complexity           0
# xlogp            21951
# heavycnt             0
# hbonddonor           0
# hbondacc             0
# rotbonds             0
# inchi                0
# isosmiles            0
# inchikey             0
# iupacname          786
# meshheadings    271158
# annothits            0
# annothitcnt          0
# aids            188606
# cidcdate             0
# sidsrcname           0
# depcatg              0
# annotation      274933
# dtype: int64

# %%
df_chem_pro[["cmpdname","cmpdsynonym","xlogp","iupacname","meshheadings","aids","annotation"]].isnull().sum()/len(df_chem_pro["cmpdname"])
# Out:
# cmpdname        0.000007
# cmpdsynonym     0.006724
# xlogp           0.079651
# iupacname       0.002852
# meshheadings    0.983918
# aids            0.684372
# annotation      0.997616
# dtype: float64

# %%
df_chem_pro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275590 entries, 0 to 275589
# Data columns (total 24 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   cid           275590 non-null  int64
#  1   cmpdname      275588 non-null  object
#  2   cmpdsynonym   273737 non-null  object
#  3   mw            275590 non-null  float64
#  4   mf            275590 non-null  object
#  5   polararea     275590 non-null  float64
#  6   complexity    275590 non-null  float64
#  7   xlogp         253639 non-null  float64
#  8   heavycnt      275590 non-null  int64
#  9   hbonddonor    275590 non-null  int64
#  10  hbondacc      275590 non-null  int64
#  11  rotbonds      275590 non-null  int64
#  12  inchi         275590 non-null  object
#  13  isosmiles     275590 non-null  object
#  14  inchikey      275590 non-null  object
#  15  iupacname     274804 non-null  object
#  16  meshheadings  4432 non-null    object
# ...

# %%
fig, axs = plt.subplots(2)
axs[0].scatter(df_chem_pro['mw'],df_chem_pro['polararea'],color='c')
axs[1].scatter(df_chem_pro['mw'],df_chem_pro['complexity'],color='g')
fig.suptitle("comparison of drug and chemical property dataset's mw with polararea and complexity")
#plt.xlabel("mw of drug and chemical property dataset")
#plt.ylabel("polararea of drug and chemical property dataset")
plt.rcParams["figure.figsize"] = (15,15)
for ax in axs.flat:
    ax.set(xlabel="mw of drug and chemical property dataset",ylabel="polararea and complexity of drug and chemical property dataset")
plt.show()

# %%
df_chem_pro_new = df_chem_pro.drop(['cmpdname','cmpdsynonym','mf','inchi','isosmiles','inchikey','iupacname','meshheadings','annothits','aids','sidsrcname','depcatg','annotation'],axis=1)
df_chem_pro_new.head()
# Out:
#    cid      mw  polararea  complexity  xlogp  heavycnt  hbonddonor  hbondacc  \
# 0    2  204.24       63.6       219.0   -0.3        14           1         4
# 1    4   75.11       46.2        22.9   -1.0         5           2         2
# 2    6  202.55       91.6       224.0    2.3        13           0         4
# 3    7  163.18       69.6       162.0    0.2        12           1         4
# 4    9  260.14      168.0       274.0   -4.8        16           7         9
#
#    rotbonds  annothitcnt  cidcdate
# 0         6            8  20050623
# 1         1           13  20050326
# 2         0           13  20050326
# 3         1            7  20050326
# 4         2            6  20050623

# %%
plt.fill_between(df_chem_pro_new['mw'],df_chem_pro_new['polararea'],alpha=0.5, linewidth=0)
plt.show()

# %%
plt.contour(df_chem_pro_new[['mw','polararea','cid']])
plt.show()

# %%
plt.hexbin(df_chem_pro_new['mw'],df_chem_pro_new['cid'],gridsize=10)
#plt.set(xlim=(-2,2), ylim=(-3,3))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14208/546945868.py in <module>
#       1 plt.hexbin(df_chem_pro_new['mw'],df_chem_pro_new['cid'],gridsize=10)
# ----> 2 plt.set(xlim=(-2,2), ylim=(-3,3))
#       3 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set'

# %%
plt.plot(df_chem_pro_new['mw'],df_chem_pro_new['cid'],'o',color='grey')
plt.tricontour(df_chem_pro_new['mw'],df_chem_pro_new['polararea'],df_chem_pro_new['cid'])
plt.show()

# %%
cmap = sns.diverging_palette(275,150,s=40,l=65,n=9)
corrma = df_chem_pro.corr()
plt.rcParams["figure.figsize"] = (20,15)
plt.plot()
sns.heatmap(corrma, cmap=cmap, annot=True, square= True)
# Out:
# <AxesSubplot:>

# %%
df_chem_pro.groupby("depcatg").count()
# Out:
#                                                     cid  cmpdname  \
# depcatg
# Chemical Vendors                                    667       667
# Chemical Vendors|Curation Efforts                    27        27
# Chemical Vendors|Curation Efforts|Governmental ...    6         6
# Chemical Vendors|Curation Efforts|Governmental ...    1         1
# Chemical Vendors|Curation Efforts|Governmental ...   72        72
# ...                                                 ...       ...
# Legacy Depositors|Subscription Services              40        40
# NIH Initiatives                                      17        17
# NIH Initiatives|Research and Development              4         4
# NIH Initiatives|Subscription Services                 1         1
# Research and Development                            295       295
#
#                                                     cmpdsynonym   mw   mf  \
# depcatg
# Chemical Vendors                                            662  667  667
# ...

# %%
df_chem_pro_number_columns = list(df_chem_pro.select_dtypes(include=['int','float']).columns)
df_chem_pro_number_columns
# Out:
# ['cid',
#  'mw',
#  'polararea',
#  'complexity',
#  'xlogp',
#  'heavycnt',
#  'hbonddonor',
#  'hbondacc',
#  'rotbonds',
#  'annothitcnt',
#  'cidcdate']
